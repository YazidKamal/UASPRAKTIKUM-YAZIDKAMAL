# %% [markdown]
# import database *"Stock.csv"*

# %%
# import module
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
# %matplotlib inline
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dacef064-386d-459a-9809-0b881d3681a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dacef064-386d-459a-9809-0b881d3681a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Membuka database *"Stock.csv"*

# %%
df = pd.read_csv('Stocks.csv')
df
# Out:
#                     Stock Name Symbol  Shares  Purchase Price ($)  \
# 0                        Apple   AAPL     100                90.0
# 1                    Microsoft   MSFT     200                32.0
# 2                   Salesforce    CRM     150                25.0
# 3                       Oracle   ORCL     250                50.0
# 4   Hewlett Packard Enterprise    HPE     500                18.0
# 5                     Alphabet   GOOG     100               225.0
# 6                        Intel   INTC     200                22.0
# 7                        Cisco   CSCO     225                18.0
# 8                     Qualcomm   QCOM     185                65.0
# 9                       Amazon   AMZN      50               800.0
# 10                      Redhat    RHT     100                95.0
# 11                    Facebook     FB    1000                17.0
# 12                     Twitter   TWTR     500                45.0
#
# ...

# %% [markdown]
# **1a**. Distribusi df pada setiap atribut *Purchase Price, Current Price*, dan *Gain/Loss* dengan grafik histogram

# %%
plt.figure(figsize=(10, 4))

plt.subplot(1, 3, 1)
sns.histplot(df['Purchase Price ($)'], kde=True, bins=10, edgecolor='w', color="k")
plt.xlabel('Purchase Price')
plt.ylabel('Frequency')
plt.title('Histogram of Purchase Price')

plt.subplot(1, 3, 2)
sns.histplot(df['Current Price ($)'], kde=True, bins=10, edgecolor='k', color="y")
plt.xlabel('Current Price')
plt.ylabel('Frequency')
plt.title('Histogram of Current Price')

plt.subplot(1, 3, 3)
sns.histplot(df['Gain/Loss ($)'], kde=True, bins=10, edgecolor='w', color="r")
plt.xlabel('Gain/Loss')
plt.ylabel('Frequency')
plt.title('Histogram of Gain/Loss')

plt.tight_layout()
plt.show()

# %% [markdown]
# **1b.** Atribut Stock *Name* dan *Symbol* yang memiliki *Dividen/Share* 5 tertinggi

# %%
data = df.sort_values(by="Dividend/Shares", ascending=False)

top_5 = data.head(5)

plt.figure(figsize=(9, 4))
sns.barplot(x="Stock Name", y="Dividend/Shares", data=top_5)
plt.title("Top 5 Stocks with Highest Dividend / Shares")
plt.show()

# %% [markdown]
# **1c**. Atribut Stock *Name* dan *Symbol* yang memiliki *Market Value* 5 tertingg

# %%
data = df.sort_values(by="Market Value ($)", ascending=False)

top_5 = data.head(5)

plt.figure(figsize=(9, 4))
sns.barplot(x="Stock Name", y="Market Value ($)", data=top_5)
plt.title("Top 5 Stocks with Highest Market Value ($)")
plt.show()

# %% [markdown]
# **1d**. Atribut Stock *Name* dan *Symbol* yang memiliki *Annual Yield* 7 tertinggi

# %%
data = df.sort_values(by="Annual Yield (%)", ascending=False)

top_7 = data.head(7)

plt.figure(figsize=(13, 4))
sns.barplot(x="Stock Name", y="Annual Yield (%)", data=top_7)
plt.title("Top 7 Stocks with Highest Annual Yield (%)")
plt.show()

# %% [markdown]
# Nama YAZID KAMAL
# NIM G 211.22.0132
# Kelas TI B
